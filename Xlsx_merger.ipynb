# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir('/home/Downloads/')
os.getcwd()
# Out:
# '/home/latlong/Downloads/MH'

# %%
import glob
glob.glob("DDW_*")
mh_data_census = pd.DataFrame()
for f in glob.glob("DDW_*"):
    df = pd.read_excel(f)
    data = data.append(df,ignore_index=True)

# %%
mh_data_census.to_excel("mh_data_census.xlsx")

# %%
#user input
name = input('city/town/village: Name ')

#check data/ lookup
mh_data_census.loc[mh_data_census['Name'] == name]
# Out:
# city/town/village: Name Mira-Bhayandar (M Corp.) WARD NO.-0051
#        State  District  Subdistt  Town/Village  Ward  EB Level  \
# 20311     27       517      4165        802786    51   0  WARD
#
#                                          Name    TRU  No_HH     ...      \
# 20311  Mira-Bhayandar (M Corp.) WARD NO.-0051  Urban  15123     ...
#
#        MARG_AL_0_3_F  MARG_HH_0_3_P  MARG_HH_0_3_M  MARG_HH_0_3_F  \
# 20311              4             20              3             17
#
#        MARG_OT_0_3_P  MARG_OT_0_3_M  MARG_OT_0_3_F  NON_WORK_P  NON_WORK_M  \
# 20311            155             95             60       38229       13961
#
#        NON_WORK_F
# 20311       24268
#
# [1 rows x 94 columns]

# %%
mh_data_census[20301:20351]
# Out:
#        State  District  Subdistt  Town/Village  Ward  EB Level  \
# 20301     27       517      4165        802786    41   0  WARD
# 20302     27       517      4165        802786    42   0  WARD
# 20303     27       517      4165        802786    43   0  WARD
# 20304     27       517      4165        802786    44   0  WARD
# 20305     27       517      4165        802786    45   0  WARD
# 20306     27       517      4165        802786    46   0  WARD
# 20307     27       517      4165        802786    47   0  WARD
# 20308     27       517      4165        802786    48   0  WARD
# 20309     27       517      4165        802786    49   0  WARD
# 20310     27       517      4165        802786    50   0  WARD
# 20311     27       517      4165        802786    51   0  WARD
# 20312     27       517      4165        802786    52   0  WARD
# 20313     27       517      4165        802786    53   0  WARD
# 20314     27       517      4165        802786    54   0  WARD
# ...

# %%
#read and store xlsx in dataframe
mh_data_ac_numbers =  pd.read_excel('MH_AC_number.xlsx', index_col=None, header=None)  # doctest: +SKIP

# %%
#convert int to type object (headers)
mh_data_ac_numbers.columns = mh_data_ac_numbers.columns.astype(str)


#renaming the headers
mh_data_ac_numbers.rename(columns={'0':'District','1':'AC_number','2':'AC_name'},inplace=True)


#check column header names
print(mh_data_ac_numbers.columns)
# Out:
# Index(['District', 'AC_number', 'AC_name'], dtype='object')

# %%
#user input
user_AC_name = input('city/town/village: Name ')
#check data
mh_data_ac_numbers.loc[mh_data_ac_numbers['AC_name']== user_AC_name]
# Out:
# city/town/village: Name Sangli
#     District AC_number AC_name
# 276   Sangli       282  Sangli

# %%
#using string match

#user input
user_AC_name = input('city/town/village: Name ')

#check data
mh_data_ac_numbers[mh_data_ac_numbers['AC_name'].str.match(user_AC_name)]
# Out:
# city/town/village: Name Aurang
#        District AC_number                 AC_name
# 107  Aurangabad       107    Aurangabad (Central)
# 108  Aurangabad       108  Aurangabad (West) (SC)
# 109  Aurangabad       109        Aurangbad (East)
